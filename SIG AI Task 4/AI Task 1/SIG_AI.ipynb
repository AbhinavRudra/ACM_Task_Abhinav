# %% [markdown]
# # AI Task 1 - Statistical Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing The Dataset

# %%
passenger = pd.read_csv('dataset.csv')

# %%
passenger
# Out:
#       No Survived  Pclass                                               Name  \
# 0      1       No       3                            Braund, Mr. Owen Harris
# 1      2      Yes       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3      Yes       3                             Heikkinen, Miss. Laina
# 3      4      Yes       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5       No       3                           Allen, Mr. William Henry
# ..   ...      ...     ...                                                ...
# 886  887       No       2                              Montvila, Rev. Juozas
# 887  888      Yes       1                       Graham, Miss. Margaret Edith
# 888  889       No       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890      Yes       1                              Behr, Mr. Karl Howell
# 890  891       No       3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# ## Summarising

# %%
passenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        891 non-null    int64
#  1   Survived  891 non-null    object
#  2   Pclass    891 non-null    int64
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    object
#  5   Age       714 non-null    float64
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    float64
#  10  Cabin     204 non-null    object
#  11  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
passenger.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# The csv file has the data of 714 passengers, with mean age close to 30.This command has summarised the column 'Age'.
#
# 1.   List item
# 2.   List item

# %%
passenger.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# This command has summarised the column 'Fare', showing max fare value going up to 512.32 & the mean lying in 32.

# %%
passenger.describe()
# Out:
#                No      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean   446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std    257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%    223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%    446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%    668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max    891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
passenger.Age.mean()
# Out:
# 29.69911764705882

# %% [markdown]
# This has displayed the mean Age of people travelling.

# %%
passenger.Fare.mean()
# Out:
# 32.204207968574636

# %%
passenger.Name.unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %% [markdown]
# This code has displayed all the names of passengers whose names are unique in the list.

# %%
passenger.Name.value_counts()
# Out:
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64

# %% [markdown]
# This has displayed every name of passenger with their repeating counts.

# %%
passenger.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
passenger.Cabin.fillna("Unknown",inplace=True)

# %%
passenger
# Out:
#      PassengerID Survived  Pclass  \
# 0              1       No       3
# 1              2      Yes       1
# 2              3      Yes       3
# 3              4      Yes       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888      Yes       1
# 888          889       No       3
# 889          890      Yes       1
# 890          891       No       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
passenger.rename(columns={'No': 'PassengerID'}, inplace=True)

# %%
x = passenger.Sex
y = passenger.Age
plt.scatter(x, y)
plt.show()

# %% [markdown]
# This graph shows that the number of people who traveled was almost of the same sex ratio. But the majority of passengers were men and there were people above the age of 70.
